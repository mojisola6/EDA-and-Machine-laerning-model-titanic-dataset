# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaburn as sns

# %%
path="C:\\Users\\User\\Desktop\\data science course\\train.csv"

# %%
train=pd.read_csv(path)

# %%
train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# # Data Accessing

# %%
# print the first five rows of the dataframe
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# print the last five rows of the dataframe
train.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
# randomly print 10rows from the dataframe
train.sample(10)
# Out:
#      PassengerId  Survived  Pclass  \
# 219          220         0       2
# 830          831         1       3
# 738          739         0       3
# 216          217         1       3
# 753          754         0       3
# 237          238         1       2
# 386          387         0       3
# 3              4         1       1
# 227          228         0       3
# 204          205         1       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 219                            Harris, Mr. Walter    male  30.0      0      0
# 830       Yasbeck, Mrs. Antoni (Selini Alexander)  female  15.0      1      0
# 738                            Ivanoff, Mr. Kanio    male   NaN      0      0
# 216                        Honkanen, Miss. Eliina  female  27.0      0      0
# 753                            Jonkoff, Mr. Lalio    male  23.0      0      0
# 237              Collyer, Miss. Marjorie "Lottie"  female   8.0      0      2
# ...

# %%
# show the summary of the dataframe
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
the dataframe consist of eleven rows
the name datatype should be change to text
the sex datatype should  be change to text
the age datatype should be change to int

# %%
# check for missing values
missing_values=train.isnull().sum()
missing_values
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
train.shape
# Out:
# (891, 12)

# %%
# how to calculate in missing values in percentage
cent_missing_values=round((train.isnull().sum()/train.shape[0])*100, 2)
cent_missing_values
# Out:
# PassengerId     0.00
# Survived        0.00
# Pclass          0.00
# Name            0.00
# Sex             0.00
# Age            19.87
# SibSp           0.00
# Parch           0.00
# Ticket          0.00
# Fare            0.00
# Cabin          77.10
# Embarked        0.22
# dtype: float64

# %%
join=pd.concat([missing_values, cent_missing_values],axis=1, keys=["missing_values", "cent_missing_values"])
join
# Out:
#              missing_values  cent_missing_values
# PassengerId               0                 0.00
# Survived                  0                 0.00
# Pclass                    0                 0.00
# Name                      0                 0.00
# Sex                       0                 0.00
# Age                     177                19.87
# SibSp                     0                 0.00
# Parch                     0                 0.00
# Ticket                    0                 0.00
# Fare                      0                 0.00
# Cabin                   687                77.10
# Embarked                  2                 0.22

# %%
join=pd.concat([missing_values, cent_missing_values],axis=1, keys=["missing_values", "cent_missing_values"])
join=join[join["missing_values"]>0]
join
# Out:
#           missing_values  cent_missing_values
# Age                  177                19.87
# Cabin                687                77.10
# Embarked               2                 0.22

# %%
# check the duplicate records
train.duplicated().sum()
# Out:
# 0

# %%
train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# Data cleaning
mean=round(train["Age"].mean())
mean
# Out:
# 30

# %%
train["Age"].fillna(mean)
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888    30.0
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
Age_mean = round(train.Age,mean())
train["Age"].fillna(Age_mean,implace=true)


# convert the datatype of age to column to int
train["age"] = train["age"].astye(int)

# %%
# to convert a series to a strings/ extracting the first of the cabin
train["Cabin"]=train["Cabin"].str[0]
train["Cabin"]
# Out:
# 0      NaN
# 1        C
# 2      NaN
# 3        C
# 4      NaN
#       ...
# 886    NaN
# 887      B
# 888    NaN
# 889      C
# 890    NaN
# Name: Cabin, Length: 891, dtype: object

# %%
# filling missing values in cabin column with the mode
mode_Cabin = train["Cabin"].mode()[0]
train["Cabin"].fillna(mode_Cabin, inplace=True)

# %%
# filling missing values in cabin column with the mode
mode_embarked = train["Cabin"].mode()[0]
train["Cabin"].fillna(mode_embarked, inplace=True)

# %% [markdown]
# # Data Exploration
# is the process of analyzing data to bring out hidden patter in the dataset
# - uni-variate Analysis: i.e analyzing one column
# - Bi-variate Analysis: i.e analyzing two columns
# - Multi-variate Analysis: i.e analyzing more than two columns

# %% [markdown]
# # Uni-variate Analysis

# %%
survived= train["Survived"].value_counts()
survived.index = ["dead", "Survived"]
survived
# Out:
# dead        549
# Survived    342
# Name: Survived, dtype: int64

# %%
# pandas plot
survived.plot(kind="bar", color=["orange"])
plt.title("count of survived rate", color="red")
plt.xticks(rotation=35, color="red")
plt.yticks(rotation=35, color="red")
plt.show()

# %% [markdown]
# # Bi-variate Analysis:

# %%
sex=train["Sex"].value_counts()
sex
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
sex.plot(kind="bar", color=["orange"])
plt.title("Count of Gender", color="red")
plt.xticks(rotation=35, color="red")
plt.yticks(rotation=35, color="red")
plt.show()
